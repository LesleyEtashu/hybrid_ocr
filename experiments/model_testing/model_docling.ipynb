# %%
# install Docling
# !pip install -U docling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.3/268.3 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.3/193.3 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 99.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 60.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 27.9 MB/s eta 0:00:00
# ...

# %%
#import tools for pdf conversion
from pathlib import Path
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions

# %%
try:
    from google.colab import files
    print("Upload your PDF file:")
    uploaded = files.upload()
    pdf_path = list(uploaded.keys())[0]
    print(f"PDF uploaded: {pdf_path}")
except ImportError:
    pdf_path = "data/benchmark"

    print(f"Running locally, using: {pdf_path}")

# %%
#set pdf conversion options
pipeline_options = PdfPipelineOptions(
    generate_picture_images=True,   # export figures/graphs as images
    generate_page_images=False,     # optional: page snapshots
    format_options=PdfFormatOption(markdown=True)  # request Markdown output
)

# %%
#Convert PDF to Markdown text
converter = DocumentConverter()

# Convert PDF
result = converter.convert(pdf_path)

# Extract Markdown text
markdown_text = result.document.export_to_markdown()
# Out:
# [INFO] 2025-11-28 08:12:11,352 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-11-28 08:12:11,360 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/det/ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-11-28 08:12:12,983 [RapidOCR] download_file.py:82: Download size: 13.83MB
# [INFO] 2025-11-28 08:12:13,211 [RapidOCR] download_file.py:95: Successfully saved to: /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-11-28 08:12:13,214 [RapidOCR] torch.py:54: Using /usr/local/lib/python3.12/dist-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-11-28 08:12:13,509 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-11-28 08:12:13,511 [RapidOCR] download_file.py:68: Initiating download: https://www.modelscope.cn/models/RapidAI/RapidOCR/resolve/v3.4.0/torch/PP-OCRv4/cls/ch_ptocr_mobile_v2.0_cls_infer.pth
# ...

# %%
print(markdown_text)
# Out:
# ## Osavuosikatsaus
#
# ## Vahva tulos vuonna 2017 koko vuoden käyttökatteen yli kolminkertaistuttua 18,0 miljoonaan
#
# Vuosi 2017 oli Afarakille merkkipaalu sekä taloudellisesti että operatiivisesti. Afarakin koko vuoden käyttökate kasvoi yli kolminkertaiseksi 5,5 miljoonasta eurosta 18,0 miljoonaan euroon liikevaihdon ollessa 198,8 miljoonaa euroa. Vaikka vankkaa tulosta tukivat parantuneet markkinaolosuhteet kuten korkeammat ferrokromin hinnat, olen erityisen ylpeä sinnikkäästä työstämme yhtiön aseman parantamiseksi vertikaalisesti integroituneena tuottajana sekä sen muutoksesta sinnikkäämmäksi ja joustavammaksi organisaatioksi. Yhtiö on selvinnyt haasteistaan erilaisilla hankkeilla ja, mikä tärkeämpää, niittänyt noususuhdanteen tarjoamat hyödyt.
#
# Guy Konsbruck Toimitusjohtaja
#
# 250ml
#
# ## Quarter 4 2017
#
# <!-- image -->
#
# ## Vahva tulos vuonna 2017 koko vuoden kŠyttškatteen yli kolminkertaistuttua 18,0 miljoonaan
#
# ...

# %%
#Save Markdown file to output folder
with open(markdown_path, "w", encoding="utf-8") as f:
    f.write(markdown_text)

print(f"Markdown saved to: {markdown_path.resolve()}")
# Out:
# Markdown saved to: /content/docling_output/output.md
